# %% [markdown]
# This notebook gives an overview of the Python plotting library - Matplotlib:
#     We will primarily be discussing pyplot, which is a plotting library similar to that of MATLAB's.
#     Subplots and plotting multiple values on a single graph are discussed herein. We also show how to load an image using Python

# %%
# Import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# Example for a simple sine function plot
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1) #You may choose 4*pi if you like complete 0 to 360 degrees sine curve view
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)
plt.show()  # You must call plt.show() to make graphics appear.

# %% [markdown]
# Multiple Plots

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])
plt.show()

# %% [markdown]
# Subplots

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# Images

# %%
# Necessary Import statement for scipy, using which we read image and pass it to the pyplot object
from scipy.misc import imread, imresize

img = imread('./cat.jpg')

# Show the original image
plt.imshow(img)
#plt.imshow(np.uint8(img))
plt.show()
